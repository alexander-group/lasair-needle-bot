# %%
from lasair_needle_bot.bot import LasairNeedleBot

# %%
bot = LasairNeedleBot()
bot.group_id = "nfranz-test12345"

#resdf = bot.check_kafka_stream(limit=1)

# %% [raw]
# resdf

# %% [raw]
# print(bot.generate_slack_msg(resdf))

# %%
bot.send_slack_message(test=False)
# Out:
# ---------------------------------------------------------------------------
# SlackApiError                             Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 bot.send_slack_message(test=False)
#
# File ~/research/alexander-group/lasair-needle-bot/lasair_needle_bot/bot.py:85, in LasairNeedleBot.send_slack_message(self, test)
#      82 if test:
#      83     return
# ---> 85 self.chat_postMessage(
#      86     channel = self.slack_channel,
#      87     text = msg,
#      88     username = self.slack_uname
#      89 )
#      90 logger.info("Sent the new Lasair NEEDLE classifications successfully!")
#
# File ~/.local/lib/lib/python3.12/site-packages/slack_sdk/web/client.py:2795, in WebClient.chat_postMessage(self, channel, text, as_user, attachments, blocks, thread_ts, reply_broadcast, unfurl_links, unfurl_media, container_id, icon_emoji, icon_url, mrkdwn, link_names, username, parse, metadata, markdown_text, **kwargs)
# ...
